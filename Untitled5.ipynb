# %%
import pandas as pd
import numpy as np

df = pd.read_csv('C:/Deakin/DataWrangling/week4/weather.csv')
df
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0        EWR  2013      1    1     0  37.04  21.92  53.97     230.0
# 1        EWR  2013      1    1     1  37.04  21.92  53.97     230.0
# 2        EWR  2013      1    1     2  37.94  21.92  52.09     230.0
# 3        EWR  2013      1    1     3  37.94  23.00  54.51     230.0
# 4        EWR  2013      1    1     4  37.94  24.08  57.04     240.0
# ...      ...   ...    ...  ...   ...    ...    ...    ...       ...
# 26125    LGA  2013     12   30    19  35.96  19.94  51.78     340.0
# 26126    LGA  2013     12   30    20  33.98  17.06  49.51     330.0
# 26127    LGA  2013     12   30    21  32.00  15.08  49.19     340.0
# 26128    LGA  2013     12   30    22  30.92  12.92  46.74     320.0
# 26129    LGA  2013     12   30    23  28.94  10.94  46.41     330.0
#
#        wind_speed  wind_gust  precip  pressure  visib         time_hour
# 0        10.35702  11.918651     0.0    1013.9   10.0  01/01/2013 01:00
# ...

# %%
# Display the first few rows
print(df.head())

# Get a concise summary of the DataFrame
print(df.info())

# Display summary statistics
print(df.describe())
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     0  37.04  21.92  53.97     230.0    10.35702
# 1    EWR  2013      1    1     1  37.04  21.92  53.97     230.0    13.80936
# 2    EWR  2013      1    1     2  37.94  21.92  52.09     230.0    12.65858
# 3    EWR  2013      1    1     3  37.94  23.00  54.51     230.0    13.80936
# 4    EWR  2013      1    1     4  37.94  24.08  57.04     240.0    14.96014
#
#    wind_gust  precip  pressure  visib         time_hour
# 0  11.918651     0.0    1013.9   10.0  01/01/2013 01:00
# 1  15.891535     0.0    1013.0   10.0  01/01/2013 02:00
# 2  14.567241     0.0    1012.6   10.0  01/01/2013 03:00
# 3  15.891535     0.0    1012.7   10.0  01/01/2013 04:00
# 4  17.215830     0.0    1012.8   10.0  01/01/2013 05:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26130 entries, 0 to 26129
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ...

# %%
# Replace the word "NA" with 0
df.replace("NA", 0, inplace=True)

# %%
# Optionally replace NaN values with 0
df.fillna(0, inplace=True)

# %%
# Verify the replacement
print("DataFrame after replacing 'NA' and NaN with 0:")
print(df.head())
# Out:
# DataFrame after replacing 'NA' and NaN with 0:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     0  37.04  21.92  53.97     230.0    10.35702
# 1    EWR  2013      1    1     1  37.04  21.92  53.97     230.0    13.80936
# 2    EWR  2013      1    1     2  37.94  21.92  52.09     230.0    12.65858
# 3    EWR  2013      1    1     3  37.94  23.00  54.51     230.0    13.80936
# 4    EWR  2013      1    1     4  37.94  24.08  57.04     240.0    14.96014
#
#    wind_gust  precip  pressure  visib         time_hour
# 0  11.918651     0.0    1013.9   10.0  01/01/2013 01:00
# 1  15.891535     0.0    1013.0   10.0  01/01/2013 02:00
# 2  14.567241     0.0    1012.6   10.0  01/01/2013 03:00
# 3  15.891535     0.0    1012.7   10.0  01/01/2013 04:00
# 4  17.215830     0.0    1012.8   10.0  01/01/2013 05:00

# %%
# Save the cleaned data if needed
df.to_csv('C:/Deakin/DataWrangling/week4/cleaned_dataset.csv', index=False)

# %%
df.dropna()
